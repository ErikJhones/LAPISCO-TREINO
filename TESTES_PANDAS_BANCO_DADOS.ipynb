# %% [markdown]
# LENDO E MOSTRANDO INFORMÇÕES DE UM ARQUIVO
# READ AND SHOW INFORMATIONS OF A PATH

# %%
import pandas as pd

df = pd.read_csv("titanic.csv") #read excel datas

df.head()
#df.head(6) #show the siz first results
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # LAST LINES
# ÚLTIMAS LINHAS

# %%
df.tail(1)
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 890          891         0       3  Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 890      0  370376  7.75   NaN        Q

# %% [markdown]
# ARCHIVE INFORMATIONS : COLUNM NAME, LINE NUMBERS PER COLUMNS, DATA TYPES AND STORAGY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# DATAFRAME INDEXATIONS

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.head(7)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# DEFINING A COLUMN AS INDEX

# %%
df.set_index('PassengerId', inplace=True)
df.head(7)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# 'Passegerld' is not a comumn, NOW IS A INDEX OF THE OUR DATAFRAME

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
df.reset_index(inplace=True)#reset the index to the original form
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %% [markdown]
# CHEKING THE COLUMNS AND YOURS RESPECTIVES VALUES
# and
# RETURN A ARRAY NUMPY WITH THE VALUES OF DATAFRAME

# %%
print (df.columns)
print('\n\n\n')
print (df.values)
# Out:
# Index(['index', 'PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
#
#
#
#
# [[0 1 0 ... 7.25 nan 'S']
#  [1 2 1 ... 71.2833 'C85' 'C']
#  [2 3 1 ... 7.925 nan 'S']
#  ...
#  [888 889 0 ... 23.45 nan 'S']
#  [889 890 1 ... 30.0 'C148' 'C']
#  [890 891 0 ... 7.75 nan 'Q']]

# %% [markdown]
# CONSULTING DATAS WITH THE LOC
# LOC: SELECT A SUBSET OF ROWS AND COLUMNS OF A DATAFRAME USING A IDEXATION BASED IN A LABEL

# %%
df.loc[1] #return all the passenger informations with the indez is 1
# Out:
# index                                                          1
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                           38
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %% [markdown]
# RETURN THE SAME INFORMATIONS FROM SEVERAL PASSENGERS

# %%
#RECIEVE A LIST
df.loc[[1,3,5]]
# Out:
#    index  PassengerId  Survived  Pclass  \
# 1      1            2         1       1
# 3      3            4         1       1
# 5      5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C
# 3      0    113803  53.1000  C123        S
# 5      0    330877   8.4583   NaN        Q

# %% [markdown]
# SELECT SEVERAL INDEX AND COLUMNS AT ONCE

# %%
df.loc[[1,2], ['Name', 'Sex', 'Age']]
# Out:
#                                                 Name     Sex   Age
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0

# %% [markdown]
# SLICE (FATIAMENTO) >> df.loc[start:stop]

# %%
df.loc[5:10:2] #five to the ten in tow in two
# Out:
#    index  PassengerId  Survived  Pclass                                 Name  \
# 5      5            6         0       3                     Moran, Mr. James
# 7      7            8         0       3       Palsson, Master. Gosta Leonard
# 9      9           10         1       2  Nasser, Mrs. Nicholas (Adele Achem)
#
#       Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 5    male   NaN      0      0  330877   8.4583   NaN        Q
# 7    male   2.0      3      1  349909  21.0750   NaN        S
# 9  female  14.0      1      0  237736  30.0708   NaN        C

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                      'B': ['B0', 'B1', 'B2', 'B3'],
                      'C': ['C0', 'C1', 'C2', 'C3'],
                       'D': ['D0', 'D1', 'D2', 'D3']},
                      index=[0, 1, 2, 3])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                       'B': ['B4', 'B5', 'B6', 'B7'],
                       'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                       index=[0, 1, 2, 3])

# %%
df2
# Out:
#     A   B   C   D
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %%
df3 = pd.DataFrame({'Z': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                      index=[8, 9, 10, 11])

# %%
df3
# Out:
#       Z    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
frames = [df1, df2, df3]

# %%
 result = pd.concat(frames)

# %%
result
# Out:
#       A    B    C    D    Z
# 0    A0   B0   C0   D0  NaN
# 1    A1   B1   C1   D1  NaN
# 2    A2   B2   C2   D2  NaN
# 3    A3   B3   C3   D3  NaN
# 0    A4   B4   C4   D4  NaN
# 1    A5   B5   C5   D5  NaN
# 2    A6   B6   C6   D6  NaN
# 3    A7   B7   C7   D7  NaN
# 8   NaN   B8   C8   D8   A8
# 9   NaN   B9   C9   D9   A9
# 10  NaN  B10  C10  D10  A10
# 11  NaN  B11  C11  D11  A11
