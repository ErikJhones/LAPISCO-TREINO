# %% [markdown]
# 5) Aplique o hold out utilizando diferentes porcentagens de divisão para separar a base iris em
# treino e teste (e.g. 60/40, 70/30, 80/20, 90/10). Crie vetores para armazenar os dados da divisão de
# treino e teste da seguinte forma:
# X_train → armazena os dados de treino
# X_test → armazena os dados de teste
# y_train → armazena a label correspondente dos dados de treino
# y_test → armazena a label correspondente dos dados de teste
# Esse padrão é extremamente adotado em problemas supervisionados de machine learning.

# %%
#bibliotecas usadas
import pandas as pd
import numpy as np
import math

# %%
df = pd.read_csv("iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
y = df['Species']
#x = df['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
x = pd.read_csv("iris.csv", usecols=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'])

# %%
from sklearn.model_selection import train_test_split
import time
# Split dataset in training and test datasets
x_train, x_test = train_test_split(df, test_size=0.4, random_state=int(time.time()))

# %%
X_train
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 74    75            6.4           2.9            4.3           1.3
# 39    40            5.1           3.4            1.5           0.2
# 124  125            6.7           3.3            5.7           2.1
# 133  134            6.3           2.8            5.1           1.5
# 129  130            7.2           3.0            5.8           1.6
# ..   ...            ...           ...            ...           ...
# 106  107            4.9           2.5            4.5           1.7
# 45    46            4.8           3.0            1.4           0.3
# 145  146            6.7           3.0            5.2           2.3
# 6      7            4.6           3.4            1.4           0.3
# 17    18            5.1           3.5            1.4           0.3
#
#              Species
# 74   Iris-versicolor
# 39       Iris-setosa
# 124   Iris-virginica
# 133   Iris-virginica
# 129   Iris-virginica
# ..               ...
# ...

# %%
# 40% teste 60%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4)
print("*****************treino******************\n",x_train)
print("\n***********saida treino**************\n",y_train)
print("\n*********** teste**************\n",x_test)
print("\n***********saida teste**************\n",y_test)
# Out:
# *****************treino******************
#       SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 121            5.6           2.8            4.9           2.0
# 40             5.0           3.5            1.3           0.3
# 107            7.3           2.9            6.3           1.8
# 142            5.8           2.7            5.1           1.9
# 140            6.7           3.1            5.6           2.4
# ..             ...           ...            ...           ...
# 58             6.6           2.9            4.6           1.3
# 99             5.7           2.8            4.1           1.3
# 148            6.2           3.4            5.4           2.3
# 27             5.2           3.5            1.5           0.2
# 85             6.0           3.4            4.5           1.6
#
# [90 rows x 4 columns]
#
# ***********saida treino**************
#  121     Iris-virginica
# 40         Iris-setosa
# 107     Iris-virginica
# 142     Iris-virginica
# ...

# %%
# 40% teste 60%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)
print("*****************treino******************\n",x_train)
print("\n***********saida treino**************\n",y_train)
print("\n*********** teste**************\n",x_test)
print("\n***********saida teste**************\n",y_test)
# Out:
# *****************treino******************
#       SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 111            6.4           2.7            5.3           1.9
# 122            7.7           2.8            6.7           2.0
# 104            6.5           3.0            5.8           2.2
# 120            6.9           3.2            5.7           2.3
# 105            7.6           3.0            6.6           2.1
# ..             ...           ...            ...           ...
# 8              4.4           2.9            1.4           0.2
# 146            6.3           2.5            5.0           1.9
# 125            7.2           3.2            6.0           1.8
# 32             5.2           4.1            1.5           0.1
# 112            6.8           3.0            5.5           2.1
#
# [105 rows x 4 columns]
#
# ***********saida treino**************
#  111    Iris-virginica
# 122    Iris-virginica
# 104    Iris-virginica
# 120    Iris-virginica
# ...

# %%
# 40% teste 60%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)
print("*****************treino******************\n",x_train)
print("\n***********saida treino**************\n",y_train)
print("\n*********** teste**************\n",x_test)
print("\n***********saida teste**************\n",y_test)
# Out:
# *****************treino******************
#       SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 77             6.7           3.0            5.0           1.7
# 8              4.4           2.9            1.4           0.2
# 42             4.4           3.2            1.3           0.2
# 6              4.6           3.4            1.4           0.3
# 18             5.7           3.8            1.7           0.3
# ..             ...           ...            ...           ...
# 144            6.7           3.3            5.7           2.5
# 128            6.4           2.8            5.6           2.1
# 12             4.8           3.0            1.4           0.1
# 22             4.6           3.6            1.0           0.2
# 33             5.5           4.2            1.4           0.2
#
# [120 rows x 4 columns]
#
# ***********saida treino**************
#  77     Iris-versicolor
# 8          Iris-setosa
# 42         Iris-setosa
# 6          Iris-setosa
# ...

# %%
# 40% teste 60%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)
print("*****************treino******************\n",x_train)
print("\n***********saida treino**************\n",y_train)
print("\n*********** teste**************\n",x_test)
print("\n***********saida teste**************\n",y_test)
# Out:
# *****************treino******************
#       SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 100            6.3           3.3            6.0           2.5
# 30             4.8           3.1            1.6           0.2
# 33             5.5           4.2            1.4           0.2
# 75             6.6           3.0            4.4           1.4
# 115            6.4           3.2            5.3           2.3
# ..             ...           ...            ...           ...
# 63             6.1           2.9            4.7           1.4
# 129            7.2           3.0            5.8           1.6
# 72             6.3           2.5            4.9           1.5
# 89             5.5           2.5            4.0           1.3
# 108            6.7           2.5            5.8           1.8
#
# [135 rows x 4 columns]
#
# ***********saida treino**************
#  100     Iris-virginica
# 30         Iris-setosa
# 33         Iris-setosa
# 75     Iris-versicolor
# ...
